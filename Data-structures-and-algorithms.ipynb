# %%
class student:
    def __init__(self):
        self.name = 'John'
        self.roll = 101
        self.marks = 78.25
    
    def __str__(self):
        return 'This is student class'

S = student()
print(S.name)
print(S.roll)
print(S.marks)
# Out:
# John
# 101
# 78.25
